# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pathlib
from IPython.display import display

# %%
# Create paths for csv
zillow_bedroom1_filepath = "../raw_data/zillow_dataset/zillow_bedroom1_rawdata.csv"
zillow_bedroom2_filepath = "../raw_data/zillow_dataset/zillow_bedroom2_rawdata.csv"
zillow_bedroom3_filepath = "../raw_data/zillow_dataset/zillow_bedroom3_rawdata.csv"
zillow_bedroom4_filepath = "../raw_data/zillow_dataset/zillow_bedroom4_rawdata.csv"
zillow_bedroom5_filepath = "../raw_data/zillow_dataset/zillow_bedroom5_rawdata.csv"
zillow_condocoop_filepath = "../raw_data/zillow_dataset/zillow_condocoop_rawdata.csv"
zillow_singlefamily_filepath = "../raw_data/zillow_dataset/zillow_singlefamily_rawdata.csv"

# %%
# Read csv
z_bed1_df = pd.read_csv(zillow_bedroom1_filepath)
z_bed2_df = pd.read_csv(zillow_bedroom2_filepath)
z_bed3_df = pd.read_csv(zillow_bedroom3_filepath)
z_bed4_df = pd.read_csv(zillow_bedroom4_filepath)
z_bed5_df = pd.read_csv(zillow_bedroom5_filepath)
z_condocoop_df = pd.read_csv(zillow_condocoop_filepath)
z_singlefamily_df = pd.read_csv(zillow_singlefamily_filepath)

# %%
# verifying data types of dfs to be merged - confirming data type of common column is matching 
z_bed1_df.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'City', 'Metro', 'CountyName', '1996-01-31',
#        ...
#        '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#        '2020-12-31', '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30'],
#       dtype='object', length=313)

# %%
merged_zillow_df = pd.merge(z_bed1_df, z_bed2_df, on=["CountyName"])
merged_zillow_df
# Out:
#          RegionID_x  SizeRank_x  RegionName_x RegionType_x StateName_x  \
# 0             61639           0         10025          Zip          NY
# 1             61639           0         10025          Zip          NY
# 2             61639           0         10025          Zip          NY
# 3             61639           0         10025          Zip          NY
# 4             61639           0         10025          Zip          NY
# ...             ...         ...           ...          ...         ...
# 1244722       92539       25955         78598          Zip          TX
# 1244723       88330       26145         69122          Zip          NE
# 1244724       88330       26145         69122          Zip          NE
# 1244725       88330       26145         69122          Zip          NE
# 1244726       88330       26145         69122          Zip          NE
#
#         State_x          City_x                      Metro_x       CountyName  \
# ...

# %%
# Name is id_vars and Course is value_vars
testing_condo_df.melt(df, id_vars =['Name'], value_vars =['Course'])
