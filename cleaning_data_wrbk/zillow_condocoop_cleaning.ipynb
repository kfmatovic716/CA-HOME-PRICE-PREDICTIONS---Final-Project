# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/PsciCat-Learners---Final-Project'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

zip_zhvi_condo_coop = "./zillow_dataset/zip_zhvi_condo_coop.csv"

# %%
# Read csv

zip_condo_coop_df = pd.read_csv(zip_zhvi_condo_coop)
pd.DataFrame(zip_condo_coop_df)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         61639         0       10025        Zip        NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# ...         ...       ...         ...        ...       ...   ...
# 10919     93733     34322       81225        Zip        CO    CO
# 10920     75924     34322       41101        Zip        KY    KY
# 10921     59147     34430        3575        Zip        TX    TX
# 10922     61694     34430       10118        Zip        NY    NY
# 10923     95851     34430       89155        Zip        NV    NV
#
#                       City                             Metro       CountyName  \
# 0                 New York       New York-Newark-Jersey City  New York County
# ...

# %%
# Create unique id for each region
zip_condo_coop_df['UniqueID'] = zip_condo_coop_df.RegionID.astype(str) + '_' + zip_condo_coop_df.RegionName.astype(str)
zip_condo_coop_df
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         61639         0       10025        Zip        NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# ...         ...       ...         ...        ...       ...   ...
# 10919     93733     34322       81225        Zip        CO    CO
# 10920     75924     34322       41101        Zip        KY    KY
# 10921     59147     34430        3575        Zip        TX    TX
# 10922     61694     34430       10118        Zip        NY    NY
# 10923     95851     34430       89155        Zip        NV    NV
#
#                       City                             Metro       CountyName  \
# 0                 New York       New York-Newark-Jersey City  New York County
# ...

# %%
# Move the UniqueID up to the front
unique_zip_condo_coop_df = zip_condo_coop_df[ ['UniqueID'] + [ col for col in zip_condo_coop_df.columns if col != 'UniqueID' ] ]
unique_zip_condo_coop_df
# Out:
#           UniqueID  RegionID  SizeRank  RegionName RegionType StateName State  \
# 0      61639_10025     61639         0       10025        Zip        NY    NY
# 1      84654_60657     84654         1       60657        Zip        IL    IL
# 2      61637_10023     61637         2       10023        Zip        NY    NY
# 3      91982_77494     91982         3       77494        Zip        TX    TX
# 4      84616_60614     84616         4       60614        Zip        IL    IL
# ...            ...       ...       ...         ...        ...       ...   ...
# 10919  93733_81225     93733     34322       81225        Zip        CO    CO
# 10920  75924_41101     75924     34322       41101        Zip        KY    KY
# 10921   59147_3575     59147     34430        3575        Zip        TX    TX
# 10922  61694_10118     61694     34430       10118        Zip        NY    NY
# 10923  95851_89155     95851     34430       89155        Zip        NV    NV
#
# ...

# %%
# remove all states that are not CA (California)
only_CA_df = zip_condo_coop_df.loc[(zip_condo_coop_df['State'] == 'CA' )]
only_CA_df
# Out:
#           UniqueID  RegionID  SizeRank  RegionName RegionType StateName State  \
# 13     97564_94109     97564        13       94109        Zip        CA    CA
# 21     96107_90250     96107        22       90250        Zip        CA    CA
# 39     97771_94565     97771        40       94565        Zip        CA    CA
# 43     96027_90046     96027        44       90046        Zip        CA    CA
# 86     97711_94501     97711        88       94501        Zip        CA    CA
# ...            ...       ...       ...         ...        ...       ...   ...
# 10839  98625_96106     98625     25574       96106        Zip        CA    CA
# 10879  96500_91759     96500     27522       91759        Zip        CA    CA
# 10899  98184_95420     98184     29964       95420        Zip        CA    CA
# 10913  98340_95646     98340     32209       95646        Zip        CA    CA
# 10914  97352_93605     97352     32244       93605        Zip        CA    CA
#
# ...

# %%
# Delete extraneous columns
delete_extraneous_columns = only_CA_df.drop(columns= [
    "StateName"
    , "RegionType"
    , "RegionID"
    , "RegionName"
    , "State"
    , "City"
    , "Metro"
])    
delete_extraneous_columns.head()
# Out:
#        UniqueID  SizeRank            CountyName  1996-01-31  1996-02-29  \
# 13  97564_94109        13  San Francisco County    304749.0    303357.0
# 21  96107_90250        22    Los Angeles County    228730.0    228394.0
# 39  97771_94565        40   Contra Costa County         NaN         NaN
# 43  96027_90046        44    Los Angeles County    145832.0    145432.0
# 86  97711_94501        88        Alameda County    181514.0    180794.0
#
#     1996-03-31  1996-04-30  1996-05-31  1996-06-30  1996-07-31  ...  \
# 13    302817.0    301640.0    301361.0    301174.0    301405.0  ...
# 21    228526.0    228267.0    228365.0    228436.0    229123.0  ...
# 39         NaN         NaN         NaN         NaN         NaN  ...
# 43    145197.0    144242.0    143096.0    141255.0    139958.0  ...
# 86    180480.0    179906.0    179810.0    179858.0    179611.0  ...
#
#     2020-07-31  2020-08-31  2020-09-30  2020-10-31  2020-11-30  2020-12-31  \
# ...

# %%
# Create a smaller df to test on 
testing_condo_df = a_ca_zip_condo_coop_df.head(5)
testing_condo_df.head()
# Out:
#        UniqueID  RegionID  SizeRank  RegionName State           City  \
# 13  97564_94109     97564        13       94109    CA  San Francisco
# 21  96107_90250     96107        22       90250    CA      Hawthorne
# 39  97771_94565     97771        40       94565    CA      Pittsburg
# 43  96027_90046     96027        44       90046    CA    Los Angeles
# 86  97711_94501     97711        88       94501    CA        Alameda
#
#                              Metro            CountyName  1996-01-31  \
# 13   San Francisco-Oakland-Hayward  San Francisco County    304749.0
# 21  Los Angeles-Long Beach-Anaheim    Los Angeles County    228730.0
# 39   San Francisco-Oakland-Hayward   Contra Costa County         NaN
# 43  Los Angeles-Long Beach-Anaheim    Los Angeles County    145832.0
# 86   San Francisco-Oakland-Hayward        Alameda County    181514.0
#
#     1996-02-29  ...  2020-07-31  2020-08-31  2020-09-30  2020-10-31  \
# ...

# %%
# How do I grab the dates in the row section

# %%
pivoted = delete_extraneous_columns.pivot(index='Region', columns='Date', values='Value')
            .reset_index()
pivoted.columns.name=None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-725f0462d212> in <module>
#       1 # Name is id_vars and Course is value_vars
# ----> 2 testing_condo_df.melt(testing_condo_df, id_vars =['UniqueID'], value_vars =['1996-01-31'])
#
# TypeError: melt() got multiple values for argument 'id_vars'

# %%
# Fill in zero for all NaN using .fillna function (optional)
df.fillna(0, inplace = True, downcast = 'infer')
df

# %%
# Years

# %%
# Create a new csv 
cleaned_edd_df.to_csv("./unemployment_dataset/EDD_cleaned_dataset.csv")
