# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/PsciCat-Learners---Final-Project'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

zip_bedroom_2 = "zillow_dataset/zip_zhvi_bedroom_2.csv"

# %%
# Read csv

zip_bedroom_2_df = pd.read_csv(zip_bedroom_2)
pd.DataFrame(zip_bedroom_2_df)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State        City  \
# 0         61639         0       10025        Zip        NY    NY    New York
# 1         84654         1       60657        Zip        IL    IL     Chicago
# 2         61637         2       10023        Zip        NY    NY    New York
# 3         91982         3       77494        Zip        TX    TX        Katy
# 4         84616         4       60614        Zip        IL    IL     Chicago
# ...         ...       ...         ...        ...       ...   ...         ...
# 27555     66881     34430       21405        Zip        MD    MD   Annapolis
# 27556     61694     34430       10118        Zip        NY    NY    New York
# 27557     95186     34430       86343        Zip        AZ    AZ  Crown King
# 27558     95851     34430       89155        Zip        NV    NV   Las Vegas
# 27559     78801     34430       47865        Zip        IN    IN    Carlisle
#
# ...
