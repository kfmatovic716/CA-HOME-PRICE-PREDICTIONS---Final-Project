# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/PsciCat-Learners---Final-Project'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

zip_zhvi_condo_coop = "zillow_dataset/zip_zhvi_condo_coop.csv"

# %%
# Read csv

zip_condo_coop_df = pd.read_csv(zip_zhvi_condo_coop)
pd.DataFrame(zip_condo_coop_df)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         61639         0       10025        Zip        NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# ...         ...       ...         ...        ...       ...   ...
# 10919     93733     34322       81225        Zip        CO    CO
# 10920     75924     34322       41101        Zip        KY    KY
# 10921     59147     34430        3575        Zip        TX    TX
# 10922     61694     34430       10118        Zip        NY    NY
# 10923     95851     34430       89155        Zip        NV    NV
#
#                       City                             Metro       CountyName  \
# 0                 New York       New York-Newark-Jersey City  New York County
# ...

# %%
# Create a smaller df to test on 
testing_condo_df = zip_condo_coop_df.head(50)
testing_condo_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    201172.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    230720.0  ...
# 2       New York-Newark-Jersey City  New York County    225235.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County         NaN  ...
# 4          Chicago-Naperville-Elgin      Cook County    264697.0  ...
#
#    2020-07-31  2020-08-31  2020-09-30  2020-10-31  2020-11-30  2020-12-31  \
# ...

# %%
# Name is id_vars and Course is value_vars
testing_condo_df.melt(df, id_vars =['Name'], value_vars =['Course'])
