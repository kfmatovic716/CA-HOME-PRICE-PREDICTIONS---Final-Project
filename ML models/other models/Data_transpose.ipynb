# %%
import pandas as pd
# Out:
# C:\Users\jmiln\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jmiln\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
# C:\Users\jmiln\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df1 = pd.read_csv('zillow_condo_clean_transpose.csv')

# %%
df1.set_index('Zip')
# Out:
#        1/31/1996  2/29/1996  3/31/1996  4/30/1996  5/31/1996  6/30/1996  \
# Zip
# 10025     201172     199926     200022     200076     200600     201133
# 60657     230720     230126     229284     228252     226725     225750
# 10023     225235     225295     225416     226252     227455     228458
# 77494     145460     145941     146927     147755     148461     148586
# 60614     264697     264331     263636     263173     262259     262146
# ...          ...        ...        ...        ...        ...        ...
# 81225     105181     105244     105399     105799     106340     106929
# 41101     106068     105942     105426     104210     103777     102728
# 3575      403837     404163     407683     406049     404764     400278
# 10118    1769224    1758007    1772568    1782498    1823969    1852243
# 89155      72689      72650      72724      72808      72972      73058
#
#        7/31/1996  8/31/1996  9/30/1996  10/31/1996  ...  7/31/2020  8/31/2020  \
# ...

# %%
df2 = df1.transpose()
df2.columns = df2.iloc[0]
df2 = df2[1:]
df2
# Out:
# Zip           10025   60657    10023   77494   60614   77449   10002   77084  \
# 1/31/1996    201172  230720   225235  145460  264697   94604  323768  113332
# 2/29/1996    199926  230126   225295  145941  264331   95392  322440  113140
# 3/31/1996    200022  229284   225416  146927  263636   96067  322079  111905
# 4/30/1996    200076  228252   226252  147755  263173   97195  323483  109418
# 5/31/1996    200600  226725   227455  148461  262259   97768  325681  107578
# ...             ...     ...      ...     ...     ...     ...     ...     ...
# 12/31/2020  1079314  428721  1130929  210326  496391  199617  924327  155280
# 1/31/2021   1080338  430485  1121601  213242  498745  201648  889867  157151
# 2/28/2021   1091289  432132  1121172  216934  501275  203843  865358  159069
# 3/31/2021   1104207  433153  1118435  221075  503147  206695  857281  160375
# 4/30/2021   1121519  434497  1120741  225963  505244  209182  876593  161897
#
# ...

# %%
df2.to_csv('zillow_condo_transpose.csv',index=False)
