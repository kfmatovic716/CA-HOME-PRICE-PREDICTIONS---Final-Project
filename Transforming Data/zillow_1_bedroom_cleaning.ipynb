# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/PsciCat-Learners---Final-Project'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv
zip_bedroom_3 = "zillow_dataset/zip_zhvi_bedroom_3.csv"

# %%
# Read csv
zip_bedroom_3_df = pd.read_csv(zip_bedroom_3)
pd.DataFrame(zip_bedroom_3_df)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         61639         0       10025        Zip        NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# ...         ...       ...         ...        ...       ...   ...
# 29220     61694     34430       10118        Zip        NY    NY
# 29221     69846     34430       28310        Zip        NC    NC
# 29222     95186     34430       86343        Zip        AZ    AZ
# 29223     95851     34430       89155        Zip        NV    NV
# 29224     66169     34430       20052        Zip        DC    DC
#
#                City                             Metro            CountyName  \
# 0          New York       New York-Newark-Jersey City       New York County
# ...
