# %% [markdown]
# # General Hospital Data - Find number of hospitals per county
# ### Cleaning the data

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np
import calendar
from time import strptime

# %%
# Create paths for csv
general_hospitals = "../hospital_dataset/general_hospitals.csv"

# %%
# Read csv
general_hospitals_df = pd.read_csv(general_hospitals)
pd.DataFrame(general_hospitals_df)
# Out:
#               X          Y  OBJECTID         ID  \
# 0    -94.945477  29.747620      8497   76777520
# 1    -82.881843  40.027143      8498  129043230
# 2    -84.168027  39.774242      8499  130045404
# 3    -80.632972  41.005169      8500  128844512
# 4    -84.199398  39.747740      8501  129845417
# ...         ...        ...       ...        ...
# 7565 -80.701221  40.372434      8492  128243953
# 7566 -81.336345  40.401257      8493  127744621
# 7567 -84.294586  39.331523      8494  128345040
# 7568 -97.283341  29.112615      8495   13879022
# 7569 -95.359806  29.711039      8496   76677004
#
#                                                    NAME  \
# 0     HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXAND...
# 1                                 WOODS AT PARKSIDE,THE
# 2                            DAYTON CHILDREN'S HOSPITAL
# 3                     VIBRA HOSPITAL OF MAHONING VALLEY
# 4                HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
# ...                                                 ...
# 7565                                 LIFE LINE HOSPITAL
# 7566                              TEN LAKES CENTER, LLC
# 7567                             LINDNER CENTER OF HOPE
# 7568                           CUERO COMMUNITY HOSPITAL
# 7569        HARRIS HEALTH SYSTEM QUENTIN MEASE HOSPITAL
#
#                                ADDRESS          CITY STATE    ZIP  \
# 0               1700 JAMES BOWIE DRIVE       BAYTOWN    TX  77520
# 1               349 OLDE RIDENOUR ROAD      COLUMBUS    OH  43230
# 2                  ONE CHILDRENS PLAZA        DAYTON    OH  45404
# 3                    8049 SOUTH AVENUE      BOARDMAN    OH  44512
# 4       ONE ELIZABETH PLACE,E3 SUITE A        DAYTON    OH  45417
# ...                                ...           ...   ...    ...
# 7565                 200 SCHOOL STREET  WINTERSVILLE    OH  43953
# 7566  819 NORTH FIRST STREET,3RD FLOOR      DENNISON    OH  44621
# 7567         4075 OLD WESTERN ROW ROAD         MASON    OH  45040
# 7568       2550 NORTH ESPLANADE STREET         CUERO    TX  79022
# 7569          3601 NORTH MACGREGOR WAY       HOUSTON    TX  77004
#
#                ZIP4  ...                  VAL_DATE  \
# 0     NOT AVAILABLE  ...  2017-12-18T00:00:00.000Z
# 1     NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# 2     NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# 3     NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# 4     NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# ...             ...  ...                       ...
# 7565  NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# 7566  NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# 7567  NOT AVAILABLE  ...  2018-04-26T00:00:00.000Z
# 7568  NOT AVAILABLE  ...  2017-12-18T00:00:00.000Z
# 7569  NOT AVAILABLE  ...  2017-12-18T00:00:00.000Z
#
#                                                 WEBSITE       STATE_ID  \
# 0     http://www.houstonmethodist.org/locations/san-...  NOT AVAILABLE
# 1                    http://www.thewoodsatparkside.com/           1815
# 2     http://www.childrensdayton.org/cms/home/index....           1411
# 3                http://www.mahoningvalleyhospital.com/           1428
# 4                   https://dayton.havenbehavioral.com/           1506
# ...                                                 ...            ...
# 7565                         http://www.llhospital.com/           1493
# 7566                     http://www.tenlakescenter.com/           1469
# 7567                    http://lindnercenterofhope.org/           1481
# 7568                           http://www.cuerohosp.org  NOT AVAILABLE
# 7569  https://www.harrishealth.org/en/services/locat...  NOT AVAILABLE
#
#                                       ALT_NAME ST_FIPS  \
# 0                                NOT AVAILABLE    48.0
# 1                                NOT AVAILABLE    39.0
# 2                                NOT AVAILABLE    39.0
# 3     MAHONING VALLEY HOSPITAL BOARDMAN CAMPUS    39.0
# 4                                NOT AVAILABLE    39.0
# ...                                        ...     ...
# 7565                             NOT AVAILABLE    39.0
# 7566                             NOT AVAILABLE    39.0
# 7567                             NOT AVAILABLE    39.0
# 7568                             NOT AVAILABLE    48.0
# 7569                             NOT AVAILABLE    48.0
#
#                                 OWNER TTL_STAFF   BEDS              TRAUMA  \
# 0                          NON-PROFIT    -999.0  182.0       NOT AVAILABLE
# 1                         PROPRIETARY    -999.0   50.0       NOT AVAILABLE
# 2                          NON-PROFIT    -999.0  155.0  PEDIATRIC LEVEL II
# 3                         PROPRIETARY    -999.0   45.0       NOT AVAILABLE
# 4                         PROPRIETARY    -999.0   32.0       NOT AVAILABLE
# ...                               ...       ...    ...                 ...
# 7565                      PROPRIETARY    -999.0   36.0       NOT AVAILABLE
# 7566                      PROPRIETARY    -999.0   16.0       NOT AVAILABLE
# 7567                       NON-PROFIT    -999.0   34.0       NOT AVAILABLE
# 7568  GOVERNMENT - DISTRICT/AUTHORITY    -999.0   49.0            LEVEL IV
# 7569                       NON-PROFIT    -999.0   49.0       NOT AVAILABLE
#
#             HELIPAD
# 0                 Y
# 1     NOT AVAILABLE
# 2                 Y
# 3     NOT AVAILABLE
# 4     NOT AVAILABLE
# ...             ...
# 7565  NOT AVAILABLE
# 7566  NOT AVAILABLE
# 7567  NOT AVAILABLE
# 7568              Y
# 7569  NOT AVAILABLE
#
# [7570 rows x 34 columns]

# %%
# remove all states that are not CA (California)
only_CA_df = general_hospitals_df.loc[(general_hospitals_df['STATE'] == 'CA') & (general_hospitals_df['COUNTRY'] == 'USA') & (general_hospitals_df['STATUS'] == 'OPEN')]
only_CA_df
# Out:
#                X          Y  OBJECTID         ID  \
# 593  -117.351005  34.073990      9093    2092324
# 594  -117.325460  34.129372      9094    3092411
# 595  -116.888208  34.246401      9095    3592315
# 596  -117.687994  34.009083      9096    5291710
# 597  -116.275139  34.131900      9097   16692252
# ...          ...        ...       ...        ...
# 6227 -122.223390  37.488848     14165   19494063
# 6228 -122.454030  37.774039     14166  167684149
# 6229 -122.405762  37.756576     14167   39094110
# 6230 -121.774458  37.249021     14168  167684183
# 6231 -120.975785  37.697028     14169  167684141
#
#                                                    NAME  \
# 593                   ARROWHEAD REGIONAL MEDICAL CENTER
# 594                         BALLARD REHABILITATION HOSP
# 595                      BEAR VALLEY COMMUNITY HOSPITAL
# 596                               CANYON RIDGE HOSPITAL
# 597                            HI-DESERT MEDICAL CENTER
# ...                                                 ...
# 6227                     KAISER FND HOSP - REDWOOD CITY
# 6228                   KENTFIELD HOSPITAL SAN FRANCISCO
# 6229  PRISCILLA CHAN & MARK ZUCKERBERG SAN FRANCISCO...
# 6230                         SAN JOSE BEHAVIORAL HEALTH
# 6231     HEALTHSOUTH REHABILITATION HOSPITAL OF MODESTO
#
#                            ADDRESS            CITY STATE    ZIP  \
# 593           400 N. PEPPER AVENUE          COLTON    CA  92324
# 594          1760 WEST 16TH STREET  SAN BERNARDINO    CA  92411
# 595            41870 GARSTIN DRIVE   BIG BEAR LAKE    CA  92315
# 596                  5353 G STREET           CHINO    CA  91710
# 597        6601 WHITE FEATHER ROAD     JOSHUA TREE    CA  92252
# ...                            ...             ...   ...    ...
# 6227       1100 VETERANS BOULEVARD    REDWOOD CITY    CA  94063
# 6228               450 STANYAN ST.   SAN FRANCISCO    CA  94117
# 6229           1001 POTRERO AVENUE   SAN FRANCISCO    CA  94110
# 6230  455 SILICON VALLEY BOULEVARD        SAN JOSE    CA  95138
# 6231                1303 MABLE AVE         MODESTO    CA  95355
#
#                ZIP4  ...                  VAL_DATE  \
# 593   NOT AVAILABLE  ...  2017-12-05T00:00:00.000Z
# 594   NOT AVAILABLE  ...  2017-12-05T00:00:00.000Z
# 595   NOT AVAILABLE  ...  2017-12-07T00:00:00.000Z
# 596   NOT AVAILABLE  ...  2017-12-05T00:00:00.000Z
# 597   NOT AVAILABLE  ...  2017-12-05T00:00:00.000Z
# ...             ...  ...                       ...
# 6227  NOT AVAILABLE  ...  2017-12-04T00:00:00.000Z
# 6228  NOT AVAILABLE  ...  2017-12-04T00:00:00.000Z
# 6229  NOT AVAILABLE  ...  2017-12-04T00:00:00.000Z
# 6230  NOT AVAILABLE  ...  2017-12-04T00:00:00.000Z
# 6231  NOT AVAILABLE  ...  2017-12-04T00:00:00.000Z
#
#                                     WEBSITE       STATE_ID  \
# 593       http://www.arrowheadmedcenter.org  NOT AVAILABLE
# 594             http://www.ballardrehab.com  NOT AVAILABLE
# 595                    http://www.bvchd.com  NOT AVAILABLE
# 596      http://www.canyonridgehospital.com  NOT AVAILABLE
# 597                     http://www.hdmc.org  NOT AVAILABLE
# ...                                     ...            ...
# 6227        http://www.kaiserpermanente.org  NOT AVAILABLE
# 6228  http://www.kentfieldsanfrancisco.com/  NOT AVAILABLE
# 6229                 https://sfgh.ucsf.edu/  NOT AVAILABLE
# 6230              https://www.sanjosebh.com  NOT AVAILABLE
# 6231         http://healthsouthmodesto.com/  NOT AVAILABLE
#
#                             ALT_NAME ST_FIPS                            OWNER  \
# 593                    NOT AVAILABLE     6.0               GOVERNMENT - LOCAL
# 594                    NOT AVAILABLE     6.0                      PROPRIETARY
# 595                    NOT AVAILABLE     6.0  GOVERNMENT - DISTRICT/AUTHORITY
# 596                    NOT AVAILABLE     6.0                      PROPRIETARY
# 597                    NOT AVAILABLE     6.0  GOVERNMENT - DISTRICT/AUTHORITY
# ...                              ...     ...                              ...
# 6227                   NOT AVAILABLE     6.0                       NON-PROFIT
# 6228                   NOT AVAILABLE     6.0                      PROPRIETARY
# 6229  SAN FRANCISCO GENERAL HOSPITAL     6.0               GOVERNMENT - LOCAL
# 6230                   NOT AVAILABLE     6.0                      PROPRIETARY
# 6231                   NOT AVAILABLE     6.0                      PROPRIETARY
#
#      TTL_STAFF   BEDS         TRAUMA        HELIPAD
# 593     -999.0  456.0             II              Y
# 594     -999.0   60.0  NOT AVAILABLE  NOT AVAILABLE
# 595     -999.0   30.0  NOT AVAILABLE              Y
# 596     -999.0  106.0  NOT AVAILABLE  NOT AVAILABLE
# 597     -999.0  179.0  NOT AVAILABLE              Y
# ...        ...    ...            ...            ...
# 6227    -999.0  149.0  NOT AVAILABLE  NOT AVAILABLE
# 6228    -999.0   60.0  NOT AVAILABLE  NOT AVAILABLE
# 6229    -999.0  375.0              I  NOT AVAILABLE
# 6230    -999.0   80.0  NOT AVAILABLE  NOT AVAILABLE
# 6231    -999.0   50.0  NOT AVAILABLE  NOT AVAILABLE
#
# [550 rows x 34 columns]

# %%
# List out all the columns names to determine what compenents are necessary 
only_CA_df.columns.tolist()
# Out:
# ['X',
#  'Y',
#  'OBJECTID',
#  'ID',
#  'NAME',
#  'ADDRESS',
#  'CITY',
#  'STATE',
#  'ZIP',
#  'ZIP4',
#  'TELEPHONE',
#  'TYPE',
#  'STATUS',
#  'POPULATION',
#  'COUNTY',
#  'COUNTYFIPS',
#  'COUNTRY',
#  'LATITUDE',
#  'LONGITUDE',
#  'NAICS_CODE',
#  'NAICS_DESC',
#  'SOURCE',
#  'SOURCEDATE',
#  'VAL_METHOD',
#  'VAL_DATE',
#  'WEBSITE',
#  'STATE_ID',
#  'ALT_NAME',
#  'ST_FIPS',
#  'OWNER',
#  'TTL_STAFF',
#  'BEDS',
#  'TRAUMA',
#  'HELIPAD']

# %%
# Delete extraneous columns
delete_extraneous_columns = only_CA_df.drop(columns= [
    "X"
    , "Y"
    , "ID"
    , "NAME"
    , "ADDRESS"
    , "CITY"
    , "STATE"
    , "ZIP4"
    , "SOURCE"
    , "NAICS_CODE"
    , "VAL_METHOD"
    , "TELEPHONE"
    , "WEBSITE"
    , "STATE_ID"
    , "ALT_NAME"
    , "ST_FIPS"
    , "OWNER"
    , "TTL_STAFF" 
    , "BEDS"
    , "TRAUMA"
    , "HELIPAD"
    , "COUNTYFIPS"
    , "SOURCEDATE"
    , "VAL_DATE"
    , "COUNTRY"
    , "ZIP"
    , "OBJECTID"
    , "TYPE"
    , "STATUS"
    , "POPULATION"
    , "LATITUDE"
    , "LONGITUDE"
    , "NAICS_DESC"
])    
delete_extraneous_columns.head()
# Out:
#              COUNTY
# 593  SAN BERNARDINO
# 594  SAN BERNARDINO
# 595  SAN BERNARDINO
# 596  SAN BERNARDINO
# 597  SAN BERNARDINO

# %% [markdown]
# ### New Dataframe - Number of Hospitals per Counties

# %%
# Create a new dataframe
new_general_hospital_df = delete_extraneous_columns
new_general_hospital_df
# Out:
#               COUNTY
# 593   SAN BERNARDINO
# 594   SAN BERNARDINO
# 595   SAN BERNARDINO
# 596   SAN BERNARDINO
# 597   SAN BERNARDINO
# ...              ...
# 6227       SAN MATEO
# 6228   SAN FRANCISCO
# 6229   SAN FRANCISCO
# 6230     SANTA CLARA
# 6231      STANISLAUS
#
# [550 rows x 1 columns]

# %%
# Number of counties 
new_general_hospital_df.nunique()
# Out:
# COUNTY    57
# dtype: int64

# %%
# Number of hospital for each county
total_hospital_bycounty = new_general_hospital_df.value_counts()
pd.DataFrame(total_hospital_bycounty)
# Out:
#                    0
# COUNTY
# LOS ANGELES      128
# ORANGE            37
# SAN DIEGO         36
# SAN BERNARDINO    31
# ALAMEDA           26
# RIVERSIDE         24
# SACRAMENTO        18
# SAN FRANCISCO     17
# SANTA CLARA       17
# KERN              15
# FRESNO            15
# VENTURA           12
# STANISLAUS        12
# SAN MATEO         11
# CONTRA COSTA      11
# SONOMA            10
# SANTA BARBARA      9
# SAN JOAQUIN        9
# SOLANO             7
# TULARE             7
# SHASTA             7
# BUTTE              7
# HUMBOLDT           6
# SAN LUIS OBISPO    6
# SANTA CRUZ         5
# PLACER             4
# MONTEREY           4
# MARIN              4
# SUTTER             4
# MENDOCINO          3
# MERCED             3
# TUOLUMNE           3
# NAPA               3
# PLUMAS             3
# EL DORADO          3
# INYO               2
# IMPERIAL           2
# KINGS              2
# LAKE               2
# YUBA               2
# YOLO               2
# MODOC              2
# SISKIYOU           2
# NEVADA             2
# MADERA             2
# SAN BENITO         2
# SIERRA             1
# AMADOR             1
# CALAVERAS          1
# COLUSA             1
# LASSEN             1
# DEL NORTE          1
# GLENN              1
# TEHAMA             1
# MONO               1
# MARIPOSA           1
# TRINITY            1

# %%
# hospitals_by_county = {}

# %%
# Group hospitals together to by each county by adding 1 to each row
# counties = new_general_hospital_df["COUNTY"]
# for county in counties:
    # print(county)

# %%
# for county in counties:                                             
#         county_name = row[2]
#         if county in hospitals_by_county:
#             hospitals_by_county[county] += 1
#         else:
#             hospitals_by_county[county] = 1
# print(county)
# Out:
# I

# %%
# # A complete list of candidates who received votes
# counties = list(hospitals_by_county.keys())                 
# county_counts = list(hospitals_by_county.values())

# %%
# total_hospitals = sum(county_counts) 
# total_hospitals

# %%
# Final cleaned csv to be used
total_hospital_bycounty.to_csv("../hospital_dataset/cleaned_hospital_ratings.csv")
