# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/PsciCat-Learners---Final-Project'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

zip_bedroom_4 = "zillow_dataset/zip_zhvi_bedroom_4.csv"

# %%
# Read csv

zip_bedroom_4_df = pd.read_csv(zip_bedroom_4)
pd.DataFrame(zip_bedroom_4_df)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State        City  \
# 0         61639         0       10025        Zip        NY    NY    New York
# 1         84654         1       60657        Zip        IL    IL     Chicago
# 2         61637         2       10023        Zip        NY    NY    New York
# 3         91982         3       77494        Zip        TX    TX        Katy
# 4         84616         4       60614        Zip        IL    IL     Chicago
# ...         ...       ...         ...        ...       ...   ...         ...
# 27032     66881     34430       21405        Zip        MD    MD   Annapolis
# 27033     69440     34430       27599        Zip        NC    NC      Durham
# 27034     95186     34430       86343        Zip        AZ    AZ  Crown King
# 27035     95851     34430       89155        Zip        NV    NV   Las Vegas
# 27036     66169     34430       20052        Zip        DC    DC  Washington
#
# ...
